# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/aryam/Onedrive/Desktop/Github/ISA-VIT/Task-2/survey_results_public.csv', index_col='Respondent')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df['YearsCode'].unique()
# Out:
# array(['4', nan, '3', '16', '13', '6', '8', '12', '2', '5', '17', '10',
#        '14', '35', '7', 'Less than 1 year', '30', '9', '26', '40', '19',
#        '15', '20', '28', '25', '1', '22', '11', '33', '50', '41', '18',
#        '34', '24', '23', '42', '27', '21', '36', '32', '39', '38'],
#       dtype=object)

# %%
df['YearsCode'].replace('Less than 1 year', 0, inplace=True)

# %%
df['YearsCode'] = df['YearsCode'].astype(float)

# %%
df['YearsCode'].mean()
# Out:
# 11.810483870967742

# %%
df['YearsCode'].replace('nan', 12, inplace=True)

# %%
df['ConvertedComp'].astype(float)
# Out:
# Respondent
# 1          NaN
# 2          NaN
# 3       8820.0
# 4      61000.0
# 5          NaN
#         ...
# 496    10500.0
# 497    68745.0
# 498    97000.0
# 499     7080.0
# 500    29858.0
# Name: ConvertedComp, Length: 499, dtype: float64

# %%
df['ConvertedComp'].mean()
# Out:
# 132389.5076923077

# %%
df['ConvertedComp'].replace('NAN', 132389.5, inplace=True)

# %%
filt = (df['ConvertedComp'] < 132389.5) & (df['YearsCode'] > 12)

# %%
df[filt]
# Out:
#                                 MainBranch Hobbyist  \
# Respondent
# 13          I am a developer by profession      Yes
# 14          I am a developer by profession      Yes
# 19          I am a developer by profession      Yes
# 22          I am a developer by profession      Yes
# 35          I am a developer by profession       No
# ...                                    ...      ...
# 468         I am a developer by profession      Yes
# 477         I am a developer by profession      Yes
# 479         I am a developer by profession       No
# 486         I am a developer by profession      Yes
# 497         I am a developer by profession      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 13          Less than once a month but more than once per ...
# 14                                    Less than once per year
# 19                                                      Never
# ...
